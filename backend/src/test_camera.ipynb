# %%
from camera.pmm_camera import PMMCamera

# %%
camera = PMMCamera()

# %%
camera.connect()

# %%
camera.take_image()
# Out:
# array([[49808,  7801, 39268, ..., 26849, 26564, 34217],
#        [36752, 61289, 28228, ..., 10769, 11492, 20153],
#        [23824, 49369, 17316, ..., 60353, 62084,  6217],
#        ...,
#        [31460, 31460,  8080, ..., 57385, 50244, 19769],
#        [31460, 31460,  8080, ...,  3524, 50244, 19769],
#        [31460, 31460, 61929, ..., 15201, 61929, 19769]], dtype=uint16)

# %%
import matplotlib.pyplot as plt

# %%
camera.set_gain(1)

# %%
plt.imshow(camera.take_image(), cmap='gray')

# %%
camera.get_exposure()
# Out:
# 10.0

# %%
camera.get_gain()
# Out:
# 1

# %%
camera.set_exposure(212.33)

# %%
camera.get_exposure()
# Out:
# 212.33

# %%
camera.set_gain(22)

# %%
camera.get_gain()
# Out:
# 22

# %%
camera.is_connected()
# Out:
# True

# %%
camera.close()

# %%
camera.is_connected()
# Out:
# False
