# %%
from stitcher.linear_stitcher import LinearStitcher
from imager.imaging_grid import ImagingGrid
import matplotlib.pyplot as plt

# %%
tiff_path = r"C:\Users\Luke\Desktop\chip-imager\chip-imaging\backend\prototyping\sample_data\test3"

# %%
grid = ImagingGrid()
grid.set_properties([0, 0], 20000, 10000, 1800, 0.62)
grid.set_imaging_width(20000)
grid.set_imaging_height(10000)
grid.set_pixels_per_um(0.62)

# %%
stitcher = LinearStitcher(tiff_path, grid)

# %%
images = stitcher._load_tiff_images()
res = stitcher._stitch_images(images)

# %%
big = stitcher._paste_images_into_canvas(res, images)
# Out:
# [0, 0]
# [1116, 0]
# [2232, 0]
# [3348, 0]
# [4464, 0]
# [5580, 0]
# [6696, 0]
# [7812, 0]
# [8928, 0]
# [10044, 0]
# [11160, 0]
# [12276, 0]
# [13392, 0]
# [0, 1116]
# [1116, 1116]
# [2232, 1116]
# [3348, 1116]
# [4464, 1116]
# [5580, 1116]
# [6696, 1116]
# [7812, 1116]
# [8928, 1116]
# [10044, 1116]
# [11160, 1116]
# [12276, 1116]
# [13392, 1116]
# [0, 2232]
# [1116, 2232]
# [2232, 2232]
# [3348, 2232]
# [4464, 2232]
# [5580, 2232]
# [6696, 2232]
# [7812, 2232]
# [8928, 2232]
# [10044, 2232]
# [11160, 2232]
# [12276, 2232]
# [13392, 2232]
# [0, 3348]
# [1116, 3348]
# [2232, 3348]
# [3348, 3348]
# [4464, 3348]
# [5580, 3348]
# [6696, 3348]
# [7812, 3348]
# [8928, 3348]
# [10044, 3348]
# [11160, 3348]
# [12276, 3348]
# [13392, 3348]
# [0, 4464]
# [1116, 4464]
# [2232, 4464]
# [3348, 4464]
# [4464, 4464]
# [5580, 4464]
# [6696, 4464]
# [7812, 4464]
# [8928, 4464]
# [10044, 4464]
# [11160, 4464]
# [12276, 4464]
# [13392, 4464]
# [0, 5580]
# [1116, 5580]
# [2232, 5580]
# [3348, 5580]
# [4464, 5580]
# [5580, 5580]
# [6696, 5580]
# [7812, 5580]
# [8928, 5580]
# [10044, 5580]
# [11160, 5580]
# [12276, 5580]
# [13392, 5580]
# [0, 6696]
# [1116, 6696]
# [2232, 6696]
# [3348, 6696]
# [4464, 6696]
# [5580, 6696]
# [6696, 6696]
# [7812, 6696]
# [8928, 6696]
# [10044, 6696]
# [11160, 6696]
# [12276, 6696]
# [13392, 6696]

# %%
plt.imshow(big, cmap='gray')

# %%
big.save('./bigguy2.png')

# %%
grid.get_cell(0).get_center_location()
# Out:
# (0, 0)

# %%
grid.get_cell(1).get_center_location()
# Out:
# (1800, 0)
